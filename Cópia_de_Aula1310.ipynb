# %% [markdown]
# <a href="https://colab.research.google.com/github/prquerque/Rodrigo-Albuquerque/blob/main/C%C3%B3pia_de_Aula1310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# Activate the environment for Linux (the system Colab runs on)
# !source my_env/bin/activate
# Out:
# /bin/bash: line 1: my_env/bin/activate: No such file or directory

# %%
# !virtualenv my_env
# Out:
# /bin/bash: line 1: virtualenv: command not found

# %%
pip install "fastapi [standart]"
# Out:
# ...
# WARNING: fastapi 0.118.2 does not provide the extra 'standart'
# ...

# %%
from pydantic import BaseModel
from typing import Optional

class Livro(BaseModel):
  título: str
  autor: str
  editora: str
  ano: Optional[int] = None

# %%
from fastapi import FastAPI
# from modelo.model import Livro # Remove this line

app = FastAPI()
biblioteca = {}

@app.get("/")
def raiz():
 return {"mensagem": "bem vindo ao API"}

@app.get("/livros")
def lista_livros():
 return {"mensagem": "Nenhum livro cadastrado"}

@app.post("/livros")
def add_livri(id:int, título:str, autor:str, editora: str=None, ano:int=None):
  biblioteca[id] = Livro(título=título, autor=autor, editora=editora, ano=ano)
  return {"mensagem": "livro adicionado com sucesso!", "livro": biblioteca[id]}
