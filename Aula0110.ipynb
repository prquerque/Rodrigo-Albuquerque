# %% [markdown]
# <a href="https://colab.research.google.com/github/prquerque/Rodrigo-Albuquerque/blob/main/Aula0110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instalar o virtualenv

# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 30.0 MB/s eta 0:00:00
# ...

# %%
# criar ambiente virtual

# !virtualenv ven
# Out:
# created virtual environment CPython3.12.11.final.0-64 in 406ms
#   creator CPython3Posix(dest=/content/ven, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# ativar ambiente virtual

# !.\venv\Scripts\activate
# Out:
# /bin/bash: line 1: .venvScriptsactivate: command not found

# %%
# Install and create the virtual environment
# !pip install virtualenv
# !virtualenv myenv

# Install packages into the virtual environment by prefixing the command
# !source /content/myenv/bin/activate; pip install package_name

# Run any other command in the environment the same way
# !source /content/myenv/bin/activate; python -c "import package_name; print('Success!')"
# Out:
# ...
# created virtual environment CPython3.12.11.final.0-64 in 168ms
#   creator CPython3Posix(dest=/content/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for package_name: filename=package_name-0.1-py3-none-any.whl size=1242 sha256=0924a75a95fe19ae05df4ae77444389b4088cc56677ef94ddc818947c04ff41d
#   Stored in directory: /root/.cache/pip/wheels/7e/a6/f5/ce521d547a4606ce65febcdcefd1c847622c6451dce9f3e8e5
# Successfully built package_name
# ...
# Success!

# %%
# !pip install "fastapi[standart]"
# Out:
# ...
# WARNING: fastapi 0.116.2 does not provide the extra 'standart'
# ...

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn
